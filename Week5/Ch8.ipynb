# %% [markdown]
# # Ch8. 어텐션

# %% [markdown]
# ## 8.3 어텐션 평가

# %%
# coding: utf-8
import sys
sys.path.append("/content/drive/MyDrive/Colab Notebooks/DLfromScratch/2/deep-learning-from-scratch-2-master")
sys.path.append("/content/drive/MyDrive/Colab Notebooks/DLfromScratch/2/deep-learning-from-scratch-2-master/ch07")
import numpy as np
import matplotlib.pyplot as plt
from dataset import sequence
from common.optimizer import Adam
from common.trainer import Trainer
from common.util import eval_seq2seq
from ch08.attention_seq2seq import AttentionSeq2seq
from ch07.seq2seq import Seq2seq
from ch07.peeky_seq2seq import PeekySeq2seq


# 데이터 읽기
(x_train, t_train), (x_test, t_test) = sequence.load_data('date.txt')
char_to_id, id_to_char = sequence.get_vocab()

# 입력 문장 반전
x_train, x_test = x_train[:, ::-1], x_test[:, ::-1]

# 하이퍼파라미터 설정
vocab_size = len(char_to_id)
wordvec_size = 16
hidden_size = 256
batch_size = 128
max_epoch = 10
max_grad = 5.0

model = AttentionSeq2seq(vocab_size, wordvec_size, hidden_size)
# model = Seq2seq(vocab_size, wordvec_size, hidden_size)
# model = PeekySeq2seq(vocab_size, wordvec_size, hidden_size)

optimizer = Adam()
trainer = Trainer(model, optimizer)

acc_list = []
for epoch in range(max_epoch):
    trainer.fit(x_train, t_train, max_epoch=1, batch_size=batch_size, max_grad=max_grad)

    correct_num = 0
    for i in range(len(x_test)):
        question, correct = x_test[[i]], t_test[[i]]
        verbose = i < 10
        correct_num += eval_seq2seq(model, question, correct, id_to_char, verbose, is_reverse=True)

    acc = float(correct_num) / len(x_test)
    acc_list.append(acc)
    print('정확도 %.3f%%' % (acc * 100))


model.save_params()
# Out:
# | 에폭 1 |  반복 1 / 351 | 시간 0[s] | 손실 4.08
# | 에폭 1 |  반복 21 / 351 | 시간 13[s] | 손실 3.09
# | 에폭 1 |  반복 41 / 351 | 시간 27[s] | 손실 1.90
# | 에폭 1 |  반복 61 / 351 | 시간 40[s] | 손실 1.72
# | 에폭 1 |  반복 81 / 351 | 시간 53[s] | 손실 1.46
# | 에폭 1 |  반복 101 / 351 | 시간 66[s] | 손실 1.19
# | 에폭 1 |  반복 121 / 351 | 시간 79[s] | 손실 1.14
# | 에폭 1 |  반복 141 / 351 | 시간 93[s] | 손실 1.09
# | 에폭 1 |  반복 161 / 351 | 시간 106[s] | 손실 1.06
# | 에폭 1 |  반복 181 / 351 | 시간 119[s] | 손실 1.04
# | 에폭 1 |  반복 201 / 351 | 시간 132[s] | 손실 1.03
# | 에폭 1 |  반복 221 / 351 | 시간 145[s] | 손실 1.02
# | 에폭 1 |  반복 241 / 351 | 시간 158[s] | 손실 1.02
# | 에폭 1 |  반복 261 / 351 | 시간 172[s] | 손실 1.01
# | 에폭 1 |  반복 281 / 351 | 시간 185[s] | 손실 1.00
# | 에폭 1 |  반복 301 / 351 | 시간 198[s] | 손실 1.00
# | 에폭 1 |  반복 321 / 351 | 시간 211[s] | 손실 1.00
# | 에폭 1 |  반복 341 / 351 | 시간 224[s] | 손실 1.00
# Q 10/15/94
# T 1994-10-15
# ☒ 1978-08-11
# ---
# Q thursday, november 13, 2008
# T 2008-11-13
# ☒ 1978-08-11
# ---
# Q Mar 25, 2003
# T 2003-03-25
# ☒ 1978-08-11
# ---
# Q Tuesday, November 22, 2016
# T 2016-11-22
# ☒ 1978-08-11
# ---
# Q Saturday, July 18, 1970
# T 1970-07-18
# ☒ 1978-08-11
# ---
# Q october 6, 1992
# T 1992-10-06
# ☒ 1978-08-11
# ---
# Q 8/23/08
# T 2008-08-23
# ☒ 1978-08-11
# ---
# Q 8/30/07
# T 2007-08-30
# ☒ 1978-08-11
# ---
# Q 10/28/13
# T 2013-10-28
# ☒ 1978-08-11
# ---
# Q sunday, november 6, 2016
# T 2016-11-06
# ☒ 1978-08-11
# ---
# 정확도 0.000%
# | 에폭 2 |  반복 1 / 351 | 시간 0[s] | 손실 1.00
# | 에폭 2 |  반복 21 / 351 | 시간 13[s] | 손실 1.00
# | 에폭 2 |  반복 41 / 351 | 시간 26[s] | 손실 0.99
# | 에폭 2 |  반복 61 / 351 | 시간 39[s] | 손실 0.99
# | 에폭 2 |  반복 81 / 351 | 시간 51[s] | 손실 0.99
# | 에폭 2 |  반복 101 / 351 | 시간 64[s] | 손실 0.99
# | 에폭 2 |  반복 121 / 351 | 시간 77[s] | 손실 0.99
# | 에폭 2 |  반복 141 / 351 | 시간 90[s] | 손실 0.98
# | 에폭 2 |  반복 161 / 351 | 시간 103[s] | 손실 0.98
# | 에폭 2 |  반복 181 / 351 | 시간 116[s] | 손실 0.97
# | 에폭 2 |  반복 201 / 351 | 시간 129[s] | 손실 0.95
# | 에폭 2 |  반복 221 / 351 | 시간 142[s] | 손실 0.94
# | 에폭 2 |  반복 241 / 351 | 시간 155[s] | 손실 0.90
# | 에폭 2 |  반복 261 / 351 | 시간 168[s] | 손실 0.83
# | 에폭 2 |  반복 281 / 351 | 시간 180[s] | 손실 0.74
# | 에폭 2 |  반복 301 / 351 | 시간 193[s] | 손실 0.66
# | 에폭 2 |  반복 321 / 351 | 시간 206[s] | 손실 0.58
# | 에폭 2 |  반복 341 / 351 | 시간 219[s] | 손실 0.47
# Q 10/15/94
# T 1994-10-15
# ☑ 1994-10-15
# ---
# Q thursday, november 13, 2008
# T 2008-11-13
# ☒ 2006-11-13
# ---
# Q Mar 25, 2003
# T 2003-03-25
# ☑ 2003-03-25
# ---
# Q Tuesday, November 22, 2016
# T 2016-11-22
# ☑ 2016-11-22
# ---
# Q Saturday, July 18, 1970
# T 1970-07-18
# ☑ 1970-07-18
# ---
# Q october 6, 1992
# T 1992-10-06
# ☑ 1992-10-06
# ---
# Q 8/23/08
# T 2008-08-23
# ☑ 2008-08-23
# ---
# Q 8/30/07
# T 2007-08-30
# ☒ 2007-08-09
# ---
# Q 10/28/13
# T 2013-10-28
# ☒ 1983-10-28
# ---
# Q sunday, november 6, 2016
# T 2016-11-06
# ☒ 2016-11-08
# ---
# 정확도 51.320%
# | 에폭 3 |  반복 1 / 351 | 시간 0[s] | 손실 0.35
# | 에폭 3 |  반복 21 / 351 | 시간 13[s] | 손실 0.30
# | 에폭 3 |  반복 41 / 351 | 시간 26[s] | 손실 0.21
# | 에폭 3 |  반복 61 / 351 | 시간 39[s] | 손실 0.14
# | 에폭 3 |  반복 81 / 351 | 시간 52[s] | 손실 0.09
# | 에폭 3 |  반복 101 / 351 | 시간 65[s] | 손실 0.07
# | 에폭 3 |  반복 121 / 351 | 시간 78[s] | 손실 0.05
# | 에폭 3 |  반복 141 / 351 | 시간 91[s] | 손실 0.04
# | 에폭 3 |  반복 161 / 351 | 시간 103[s] | 손실 0.03
# | 에폭 3 |  반복 181 / 351 | 시간 117[s] | 손실 0.03
# | 에폭 3 |  반복 201 / 351 | 시간 129[s] | 손실 0.02
# | 에폭 3 |  반복 221 / 351 | 시간 142[s] | 손실 0.02
# | 에폭 3 |  반복 241 / 351 | 시간 155[s] | 손실 0.02
# | 에폭 3 |  반복 261 / 351 | 시간 168[s] | 손실 0.01
# | 에폭 3 |  반복 281 / 351 | 시간 182[s] | 손실 0.01
# | 에폭 3 |  반복 301 / 351 | 시간 195[s] | 손실 0.01
# | 에폭 3 |  반복 321 / 351 | 시간 208[s] | 손실 0.01
# | 에폭 3 |  반복 341 / 351 | 시간 221[s] | 손실 0.01
# Q 10/15/94
# T 1994-10-15
# ☑ 1994-10-15
# ---
# Q thursday, november 13, 2008
# T 2008-11-13
# ☑ 2008-11-13
# ---
# Q Mar 25, 2003
# T 2003-03-25
# ☑ 2003-03-25
# ---
# Q Tuesday, November 22, 2016
# T 2016-11-22
# ☑ 2016-11-22
# ---
# Q Saturday, July 18, 1970
# T 1970-07-18
# ☑ 1970-07-18
# ---
# Q october 6, 1992
# T 1992-10-06
# ☑ 1992-10-06
# ---
# Q 8/23/08
# T 2008-08-23
# ☑ 2008-08-23
# ---
# Q 8/30/07
# T 2007-08-30
# ☑ 2007-08-30
# ---
# Q 10/28/13
# T 2013-10-28
# ☑ 2013-10-28
# ---
# Q sunday, november 6, 2016
# T 2016-11-06
# ☑ 2016-11-06
# ---
# 정확도 99.900%
# | 에폭 4 |  반복 1 / 351 | 시간 0[s] | 손실 0.01
# | 에폭 4 |  반복 21 / 351 | 시간 14[s] | 손실 0.01
# | 에폭 4 |  반복 41 / 351 | 시간 27[s] | 손실 0.01
# | 에폭 4 |  반복 61 / 351 | 시간 41[s] | 손실 0.01
# | 에폭 4 |  반복 81 / 351 | 시간 54[s] | 손실 0.01
# | 에폭 4 |  반복 101 / 351 | 시간 68[s] | 손실 0.01
# | 에폭 4 |  반복 121 / 351 | 시간 81[s] | 손실 0.00
# | 에폭 4 |  반복 141 / 351 | 시간 95[s] | 손실 0.01
# | 에폭 4 |  반복 161 / 351 | 시간 109[s] | 손실 0.00
# | 에폭 4 |  반복 181 / 351 | 시간 122[s] | 손실 0.00
# | 에폭 4 |  반복 201 / 351 | 시간 136[s] | 손실 0.00
# | 에폭 4 |  반복 221 / 351 | 시간 150[s] | 손실 0.00
# | 에폭 4 |  반복 241 / 351 | 시간 164[s] | 손실 0.00
# | 에폭 4 |  반복 261 / 351 | 시간 177[s] | 손실 0.00
# | 에폭 4 |  반복 281 / 351 | 시간 191[s] | 손실 0.00
# | 에폭 4 |  반복 301 / 351 | 시간 204[s] | 손실 0.00
# | 에폭 4 |  반복 321 / 351 | 시간 218[s] | 손실 0.00
# | 에폭 4 |  반복 341 / 351 | 시간 231[s] | 손실 0.00
# Q 10/15/94
# T 1994-10-15
# ☑ 1994-10-15
# ---
# Q thursday, november 13, 2008
# T 2008-11-13
# ☑ 2008-11-13
# ---
# Q Mar 25, 2003
# T 2003-03-25
# ☑ 2003-03-25
# ---
# Q Tuesday, November 22, 2016
# T 2016-11-22
# ☑ 2016-11-22
# ---
# Q Saturday, July 18, 1970
# T 1970-07-18
# ☑ 1970-07-18
# ---
# Q october 6, 1992
# T 1992-10-06
# ☑ 1992-10-06
# ---
# Q 8/23/08
# T 2008-08-23
# ☑ 2008-08-23
# ---
# Q 8/30/07
# T 2007-08-30
# ☑ 2007-08-30
# ---
# Q 10/28/13
# T 2013-10-28
# ☑ 2013-10-28
# ---
# Q sunday, november 6, 2016
# T 2016-11-06
# ☑ 2016-11-06
# ---
# 정확도 99.900%
# | 에폭 5 |  반복 1 / 351 | 시간 0[s] | 손실 0.00
# | 에폭 5 |  반복 21 / 351 | 시간 14[s] | 손실 0.00
# | 에폭 5 |  반복 41 / 351 | 시간 27[s] | 손실 0.00
# | 에폭 5 |  반복 61 / 351 | 시간 41[s] | 손실 0.00
# | 에폭 5 |  반복 81 / 351 | 시간 54[s] | 손실 0.00
# | 에폭 5 |  반복 101 / 351 | 시간 68[s] | 손실 0.00
# | 에폭 5 |  반복 121 / 351 | 시간 81[s] | 손실 0.00
# | 에폭 5 |  반복 141 / 351 | 시간 95[s] | 손실 0.00
# | 에폭 5 |  반복 161 / 351 | 시간 109[s] | 손실 0.00
# | 에폭 5 |  반복 181 / 351 | 시간 122[s] | 손실 0.02
# | 에폭 5 |  반복 201 / 351 | 시간 136[s] | 손실 0.01
# | 에폭 5 |  반복 221 / 351 | 시간 149[s] | 손실 0.01
# | 에폭 5 |  반복 241 / 351 | 시간 163[s] | 손실 0.00
# | 에폭 5 |  반복 261 / 351 | 시간 176[s] | 손실 0.00
# | 에폭 5 |  반복 281 / 351 | 시간 190[s] | 손실 0.00
# | 에폭 5 |  반복 301 / 351 | 시간 203[s] | 손실 0.00
# | 에폭 5 |  반복 321 / 351 | 시간 217[s] | 손실 0.00
# | 에폭 5 |  반복 341 / 351 | 시간 230[s] | 손실 0.00
# Q 10/15/94
# T 1994-10-15
# ☑ 1994-10-15
# ---
# Q thursday, november 13, 2008
# T 2008-11-13
# ☑ 2008-11-13
# ---
# Q Mar 25, 2003
# T 2003-03-25
# ☑ 2003-03-25
# ---
# Q Tuesday, November 22, 2016
# T 2016-11-22
# ☑ 2016-11-22
# ---
# Q Saturday, July 18, 1970
# T 1970-07-18
# ☑ 1970-07-18
# ---
# Q october 6, 1992
# T 1992-10-06
# ☑ 1992-10-06
# ---
# Q 8/23/08
# T 2008-08-23
# ☑ 2008-08-23
# ---
# Q 8/30/07
# T 2007-08-30
# ☑ 2007-08-30
# ---
# Q 10/28/13
# T 2013-10-28
# ☑ 2013-10-28
# ---
# Q sunday, november 6, 2016
# T 2016-11-06
# ☑ 2016-11-06
# ---
# 정확도 100.000%
# | 에폭 6 |  반복 1 / 351 | 시간 0[s] | 손실 0.00
# | 에폭 6 |  반복 21 / 351 | 시간 14[s] | 손실 0.00
# | 에폭 6 |  반복 41 / 351 | 시간 27[s] | 손실 0.00
# | 에폭 6 |  반복 61 / 351 | 시간 41[s] | 손실 0.00
# | 에폭 6 |  반복 81 / 351 | 시간 54[s] | 손실 0.00
# | 에폭 6 |  반복 101 / 351 | 시간 68[s] | 손실 0.00
# | 에폭 6 |  반복 121 / 351 | 시간 81[s] | 손실 0.00
# | 에폭 6 |  반복 141 / 351 | 시간 95[s] | 손실 0.00
# | 에폭 6 |  반복 161 / 351 | 시간 109[s] | 손실 0.00
# | 에폭 6 |  반복 181 / 351 | 시간 122[s] | 손실 0.00
# | 에폭 6 |  반복 201 / 351 | 시간 136[s] | 손실 0.00
# | 에폭 6 |  반복 221 / 351 | 시간 150[s] | 손실 0.00
# | 에폭 6 |  반복 241 / 351 | 시간 163[s] | 손실 0.00
# | 에폭 6 |  반복 261 / 351 | 시간 177[s] | 손실 0.00
# | 에폭 6 |  반복 281 / 351 | 시간 190[s] | 손실 0.00
# | 에폭 6 |  반복 301 / 351 | 시간 204[s] | 손실 0.00
# | 에폭 6 |  반복 321 / 351 | 시간 217[s] | 손실 0.00
# | 에폭 6 |  반복 341 / 351 | 시간 231[s] | 손실 0.00
# Q 10/15/94
# T 1994-10-15
# ☑ 1994-10-15
# ---
# Q thursday, november 13, 2008
# T 2008-11-13
# ☑ 2008-11-13
# ---
# Q Mar 25, 2003
# T 2003-03-25
# ☑ 2003-03-25
# ---
# Q Tuesday, November 22, 2016
# T 2016-11-22
# ☑ 2016-11-22
# ---
# Q Saturday, July 18, 1970
# T 1970-07-18
# ☑ 1970-07-18
# ---
# Q october 6, 1992
# T 1992-10-06
# ☑ 1992-10-06
# ---
# Q 8/23/08
# T 2008-08-23
# ☑ 2008-08-23
# ---
# Q 8/30/07
# T 2007-08-30
# ☑ 2007-08-30
# ---
# Q 10/28/13
# T 2013-10-28
# ☑ 2013-10-28
# ---
# Q sunday, november 6, 2016
# T 2016-11-06
# ☑ 2016-11-06
# ---
# 정확도 100.000%
# | 에폭 7 |  반복 1 / 351 | 시간 0[s] | 손실 0.00
# | 에폭 7 |  반복 21 / 351 | 시간 14[s] | 손실 0.00
# | 에폭 7 |  반복 41 / 351 | 시간 28[s] | 손실 0.00
# | 에폭 7 |  반복 61 / 351 | 시간 41[s] | 손실 0.00
# | 에폭 7 |  반복 81 / 351 | 시간 55[s] | 손실 0.00
# | 에폭 7 |  반복 101 / 351 | 시간 69[s] | 손실 0.00
# | 에폭 7 |  반복 121 / 351 | 시간 83[s] | 손실 0.00
# | 에폭 7 |  반복 141 / 351 | 시간 96[s] | 손실 0.00
# | 에폭 7 |  반복 161 / 351 | 시간 110[s] | 손실 0.00
# | 에폭 7 |  반복 181 / 351 | 시간 123[s] | 손실 0.00
# | 에폭 7 |  반복 201 / 351 | 시간 137[s] | 손실 0.00
# | 에폭 7 |  반복 221 / 351 | 시간 151[s] | 손실 0.00
# | 에폭 7 |  반복 241 / 351 | 시간 164[s] | 손실 0.00
# | 에폭 7 |  반복 261 / 351 | 시간 178[s] | 손실 0.00
# | 에폭 7 |  반복 281 / 351 | 시간 192[s] | 손실 0.00
# | 에폭 7 |  반복 301 / 351 | 시간 205[s] | 손실 0.00
# | 에폭 7 |  반복 321 / 351 | 시간 219[s] | 손실 0.00
# | 에폭 7 |  반복 341 / 351 | 시간 233[s] | 손실 0.00
# Q 10/15/94
# T 1994-10-15
# ☑ 1994-10-15
# ---
# Q thursday, november 13, 2008
# T 2008-11-13
# ☑ 2008-11-13
# ---
# Q Mar 25, 2003
# T 2003-03-25
# ☑ 2003-03-25
# ---
# Q Tuesday, November 22, 2016
# T 2016-11-22
# ☑ 2016-11-22
# ---
# Q Saturday, July 18, 1970
# T 1970-07-18
# ☑ 1970-07-18
# ---
# Q october 6, 1992
# T 1992-10-06
# ☑ 1992-10-06
# ---
# Q 8/23/08
# T 2008-08-23
# ☑ 2008-08-23
# ---
# Q 8/30/07
# T 2007-08-30
# ☑ 2007-08-30
# ---
# Q 10/28/13
# T 2013-10-28
# ☑ 2013-10-28
# ---
# Q sunday, november 6, 2016
# T 2016-11-06
# ☑ 2016-11-06
# ---
# 정확도 100.000%
# | 에폭 8 |  반복 1 / 351 | 시간 0[s] | 손실 0.00
# | 에폭 8 |  반복 21 / 351 | 시간 14[s] | 손실 0.00
# | 에폭 8 |  반복 41 / 351 | 시간 27[s] | 손실 0.00
# | 에폭 8 |  반복 61 / 351 | 시간 41[s] | 손실 0.00
# | 에폭 8 |  반복 81 / 351 | 시간 54[s] | 손실 0.00
# | 에폭 8 |  반복 101 / 351 | 시간 68[s] | 손실 0.00
# | 에폭 8 |  반복 121 / 351 | 시간 81[s] | 손실 0.00
# | 에폭 8 |  반복 141 / 351 | 시간 94[s] | 손실 0.00
# | 에폭 8 |  반복 161 / 351 | 시간 108[s] | 손실 0.00
# | 에폭 8 |  반복 181 / 351 | 시간 122[s] | 손실 0.00
# | 에폭 8 |  반복 201 / 351 | 시간 135[s] | 손실 0.00
# | 에폭 8 |  반복 221 / 351 | 시간 148[s] | 손실 0.00
# | 에폭 8 |  반복 241 / 351 | 시간 162[s] | 손실 0.00
# | 에폭 8 |  반복 261 / 351 | 시간 175[s] | 손실 0.00
# | 에폭 8 |  반복 281 / 351 | 시간 188[s] | 손실 0.00
# | 에폭 8 |  반복 301 / 351 | 시간 202[s] | 손실 0.00
# | 에폭 8 |  반복 321 / 351 | 시간 215[s] | 손실 0.00
# | 에폭 8 |  반복 341 / 351 | 시간 228[s] | 손실 0.00
# Q 10/15/94
# T 1994-10-15
# ☑ 1994-10-15
# ---
# Q thursday, november 13, 2008
# T 2008-11-13
# ☑ 2008-11-13
# ---
# Q Mar 25, 2003
# T 2003-03-25
# ☑ 2003-03-25
# ---
# Q Tuesday, November 22, 2016
# T 2016-11-22
# ☑ 2016-11-22
# ---
# Q Saturday, July 18, 1970
# T 1970-07-18
# ☑ 1970-07-18
# ---
# Q october 6, 1992
# T 1992-10-06
# ☑ 1992-10-06
# ---
# Q 8/23/08
# T 2008-08-23
# ☑ 2008-08-23
# ---
# Q 8/30/07
# T 2007-08-30
# ☑ 2007-08-30
# ---
# Q 10/28/13
# T 2013-10-28
# ☑ 2013-10-28
# ---
# Q sunday, november 6, 2016
# T 2016-11-06
# ☑ 2016-11-06
# ---
# 정확도 100.000%
# | 에폭 9 |  반복 1 / 351 | 시간 0[s] | 손실 0.00
# | 에폭 9 |  반복 21 / 351 | 시간 14[s] | 손실 0.00
# | 에폭 9 |  반복 41 / 351 | 시간 27[s] | 손실 0.00
# | 에폭 9 |  반복 61 / 351 | 시간 40[s] | 손실 0.00
# | 에폭 9 |  반복 81 / 351 | 시간 54[s] | 손실 0.00
# | 에폭 9 |  반복 101 / 351 | 시간 67[s] | 손실 0.00
# | 에폭 9 |  반복 121 / 351 | 시간 81[s] | 손실 0.00
# | 에폭 9 |  반복 141 / 351 | 시간 94[s] | 손실 0.00
# | 에폭 9 |  반복 161 / 351 | 시간 108[s] | 손실 0.00
# | 에폭 9 |  반복 181 / 351 | 시간 121[s] | 손실 0.00
# | 에폭 9 |  반복 201 / 351 | 시간 134[s] | 손실 0.00
# | 에폭 9 |  반복 221 / 351 | 시간 148[s] | 손실 0.00
# | 에폭 9 |  반복 241 / 351 | 시간 161[s] | 손실 0.00
# | 에폭 9 |  반복 261 / 351 | 시간 175[s] | 손실 0.00
# | 에폭 9 |  반복 281 / 351 | 시간 188[s] | 손실 0.00
# | 에폭 9 |  반복 301 / 351 | 시간 202[s] | 손실 0.00
# | 에폭 9 |  반복 321 / 351 | 시간 215[s] | 손실 0.00
# | 에폭 9 |  반복 341 / 351 | 시간 229[s] | 손실 0.00
# Q 10/15/94
# T 1994-10-15
# ☑ 1994-10-15
# ---
# Q thursday, november 13, 2008
# T 2008-11-13
# ☑ 2008-11-13
# ---
# Q Mar 25, 2003
# T 2003-03-25
# ☑ 2003-03-25
# ---
# Q Tuesday, November 22, 2016
# T 2016-11-22
# ☑ 2016-11-22
# ---
# Q Saturday, July 18, 1970
# T 1970-07-18
# ☑ 1970-07-18
# ---
# Q october 6, 1992
# T 1992-10-06
# ☑ 1992-10-06
# ---
# Q 8/23/08
# T 2008-08-23
# ☑ 2008-08-23
# ---
# Q 8/30/07
# T 2007-08-30
# ☑ 2007-08-30
# ---
# Q 10/28/13
# T 2013-10-28
# ☑ 2013-10-28
# ---
# Q sunday, november 6, 2016
# T 2016-11-06
# ☑ 2016-11-06
# ---
# 정확도 100.000%
# | 에폭 10 |  반복 1 / 351 | 시간 0[s] | 손실 0.00
# | 에폭 10 |  반복 21 / 351 | 시간 13[s] | 손실 0.00
# | 에폭 10 |  반복 41 / 351 | 시간 26[s] | 손실 0.00
# | 에폭 10 |  반복 61 / 351 | 시간 40[s] | 손실 0.00
# | 에폭 10 |  반복 81 / 351 | 시간 53[s] | 손실 0.00
# | 에폭 10 |  반복 101 / 351 | 시간 67[s] | 손실 0.00
# | 에폭 10 |  반복 121 / 351 | 시간 80[s] | 손실 0.00
# | 에폭 10 |  반복 141 / 351 | 시간 93[s] | 손실 0.00
# | 에폭 10 |  반복 161 / 351 | 시간 106[s] | 손실 0.00
# | 에폭 10 |  반복 181 / 351 | 시간 119[s] | 손실 0.00
# | 에폭 10 |  반복 201 / 351 | 시간 132[s] | 손실 0.00
# | 에폭 10 |  반복 221 / 351 | 시간 145[s] | 손실 0.00
# | 에폭 10 |  반복 241 / 351 | 시간 158[s] | 손실 0.00
# | 에폭 10 |  반복 261 / 351 | 시간 171[s] | 손실 0.00
# | 에폭 10 |  반복 281 / 351 | 시간 184[s] | 손실 0.00
# | 에폭 10 |  반복 301 / 351 | 시간 198[s] | 손실 0.00
# | 에폭 10 |  반복 321 / 351 | 시간 211[s] | 손실 0.00
# | 에폭 10 |  반복 341 / 351 | 시간 225[s] | 손실 0.00
# Q 10/15/94
# T 1994-10-15
# ☑ 1994-10-15
# ---
# Q thursday, november 13, 2008
# T 2008-11-13
# ☑ 2008-11-13
# ---
# Q Mar 25, 2003
# T 2003-03-25
# ☑ 2003-03-25
# ---
# Q Tuesday, November 22, 2016
# T 2016-11-22
# ☑ 2016-11-22
# ---
# Q Saturday, July 18, 1970
# T 1970-07-18
# ☑ 1970-07-18
# ---
# Q october 6, 1992
# T 1992-10-06
# ☑ 1992-10-06
# ---
# Q 8/23/08
# T 2008-08-23
# ☑ 2008-08-23
# ---
# Q 8/30/07
# T 2007-08-30
# ☑ 2007-08-30
# ---
# Q 10/28/13
# T 2013-10-28
# ☑ 2013-10-28
# ---
# Q sunday, november 6, 2016
# T 2016-11-06
# ☑ 2016-11-06
# ---
# 정확도 100.000%

# %%
# 그래프 그리기
x = np.arange(len(acc_list))
plt.plot(x, acc_list, marker='o')
plt.xlabel('에폭')
plt.ylabel('정확도')
plt.ylim(-0.05, 1.05)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 50640 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54253 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51221 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54869 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 50640 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 54253 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 51221 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 54869 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0, flags=flags)
